# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Shital Gondaliya, Assistant Professor, MBIT College, V V Nagar </b>

# %% [markdown]
# *I am intrested in Data Scicence because as per the current trends in industry and wide requirement in the domains like business, healthcare etc.*

# %% [markdown]
# ### The following cell will perform the operation of addition which of type binary arithmetic

# %%
20 + 30
# Out:
# 50

# %% [markdown]
# 1. Tea
# 2. Coffee
# 3. Ice Cream
#
# ---
# Horizontal Rule
#
# Table as follows
#
# | Tables        | Are           | Cool  |
# | ------------- |:-------------:| -----:|
# | col 3 is      | right-aligned | $1600 |
# | col 2 is      | centered      |   $12 |
# | zebra stripes | are neat      |    $1 |
#
# Hyperlink
#
# [Click me to open Google.com](https://www.google.com)
